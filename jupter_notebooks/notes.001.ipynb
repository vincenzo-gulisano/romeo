# %% [markdown]
# **231127**
#
# - very first notebook
# - for now, just trying to create a first setup that can be used to interface Java (for the SPE) and Python (for the reinforcement learning actor)
# - communication between the two will happen via Kafka
# - Created a couple of Java interfaces and classes
# - now installing Kafka (following this https://kafka.apache.org/quickstart)
# - now modifying the JPComm class to communicate with Kafka
#   - We will need to establish some form of basic coordination between Java and Python so that Java (the SPE) can start running once both are in place
#
#
#   **231130**
#
#   - Trying to move the aggregate+compressor to this project:
#     - Update pom.xml
