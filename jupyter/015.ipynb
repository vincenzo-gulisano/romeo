# %% [markdown]
# 2024/09/19 - This is the first experiment for the ICPE resubmission.
#
# We are trying to re-run the Synthetic and Linear Road use cases with the new reward function, after noticing the previous implementation was actually buggy.
#
# I do not remember right now the exact procedure we were following, so I am going to simply try to re-create the same graphs we have in the paper but with the new data.

# %%
# !mkdir -p data/exp15/WEL-AW/synthetic/15.1

# %%
# !scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/WEAAW/synthetic/1/900/5000000000/10/. data/exp15/WEL-AW/synthetic/15.1

# %%
# !./scripts/create_plots_for_exp.sh data/exp15/WEL-AW True synthetic/15.1

# %% [markdown]
# The graph creation seems to work... by looking at the graph I am remembering some of the challenges we had:
# - agent doing some crazy stuff towards the end of the experiment
# - probabilities getting better but then very strange after a certain number of experiments
# - need to check for specific events/look at specific episodes to understand what is happening

# %%
# !python plotting/create_summary_data.py data/exp15/WEL-AW/synthetic

# %%
# !python plotting/paper_plot_baselines_vs_agent_icpe.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp15/WEL-AW/synthetic/baselines_data.csv data/exp15/WEL-AW/synthetic/s_baseline_vs_agent.pdf data/exp15/WEL-AW/synthetic/15.1/actionsprobs.csv 149 synthetic wel-aw_synthetic

# %%
# !mkdir -p data/exp15/WEL-AW/linearroad/15.1
# !scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15/linear/4_WEAAW/. data/exp15/WEL-AW/linearroad/15.1/
# !./scripts/create_plots_for_exp.sh data/exp15/WEL-AW True linearroad/15.1
# !python plotting/create_summary_data.py data/exp15/WEL-AW/linearroad
# !python plotting/paper_plot_baselines_vs_agent_icpe.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp15/WEL-AW/linearroad/baselines_data.csv data/exp15/WEL-AW/linearroad/lr_baseline_vs_agent.pdf data/exp15/WEL-AW/linearroad/15.1/actionsprobs.csv 149 linearroad 15.1

# %%
# !python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp15/WEL-AW/synthetic/baselines_data.csv data/exp15/WEL-AW/synthetic/s_baseline_vs_agent.pdf data/exp15/WEL-AW/synthetic/15.1/actionsprobs.csv 149 synthetic wel-aw_synthetic
# !python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp15/WEL-AW/linearroad/baselines_data.csv data/exp15/WEL-AW/linearroad/lr_baseline_vs_agent.pdf data/exp15/WEL-AW/linearroad/15.1/actionsprobs.csv 149 linearroad 15.1
# Out:
# python: can't open file '/Users/vinmas/repositories/romeo/jupyter/plotting/paper_plot_baselines_vs_agent_icpe_single_column.py': [Errno 2] No such file or directory
# python: can't open file '/Users/vinmas/repositories/romeo/jupyter/plotting/paper_plot_baselines_vs_agent_icpe_single_column.py': [Errno 2] No such file or directory

# %% [markdown]
# Now finding again the scripts to plot the various policies
# !python plotting/paper_plot_agent_policies_icpe_singlecolumn.py data/10/synthetic-CCR/1/900/s_rate.csv data/exp14_policies_synth5WA/merged.csv data/exp14/policies_synthetic_5s.
# pdf synthetic5s
# !python plotting/paper_plot_agent_policies_icpe_singlecolumn.py data/10/linearroad-CCR/5/600/lr_rate.csv data/exp14/merged.csv data/exp14/policies_linear.pdf linearroad
# !python plotting/paper_plot_agent_policies_icpe_singlecolumn.py data/10/synthetic-CCR/1/900/s_rate.csv data/exp14/merged.csv data/exp14/policies_synthetic.pdf synthetic

# %% [markdown]
# Creating again the policies graphs, but this time with the new experiments
#
# - `mkdir -p data/exp15/WEL-OB/15.3`
# - `mkdir -p data/exp15/EL-OB/15.3`
# - `mkdir -p data/exp15/L-OB/15.3`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15.2/1_WEAOB/linear data/exp15/WEL-OB/15.3/`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15.2/1_WEAOB/synthetic data/exp15/WEL-OB/15.3/`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15.2/2_EAOB/linear data/exp15/EL-OB/15.3/`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15.2/2_EAOB/synthetic data/exp15/EL-OB/15.3/`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15.2/3_AOB/linear data/exp15/L-OB/15.3/`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15.2/3_AOB/synthetic data/exp15/L-OB/15.3/`
# - `./scripts/create_plots_for_exp.sh data/exp15/WEL-OB True 15.3/linear`
# - `./scripts/create_plots_for_exp.sh data/exp15/WEL-OB True 15.3/synthetic`
# - `./scripts/create_plots_for_exp.sh data/exp15/EL-OB True 15.3/linear`
# - `./scripts/create_plots_for_exp.sh data/exp15/EL-OB True 15.3/synthetic`
# - `./scripts/create_plots_for_exp.sh data/exp15/L-OB True 15.3/linear`
# - `./scripts/create_plots_for_exp.sh data/exp15/L-OB True 15.3/synthetic`
# - `python plotting/create_summary_data.py data/exp15/WEL-OB/15.3`
# - `python plotting/create_summary_data.py data/exp15/EL-OB/15.3`
# - `python plotting/create_summary_data.py data/exp15/L-OB/15.3`
#
# Modifying ids manually...
#
# - `find data/exp15/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp15/merged.csv`
# - `python plotting/paper_plot_agent_policies_icpe_singlecolumn.py data/10/linearroad-CCR/5/600/lr_rate.csv data/exp15/merged.csv data/exp15/policies_linear.pdf linearroad`
# - `python plotting/paper_plot_agent_policies_icpe_singlecolumn.py data/10/synthetic-CCR/1/900/s_rate.csv data/exp15/merged.csv data/exp15/policies_synthetic.pdf synthetic`
#
# - `python plotting/paper_plot_agent_policies_icpe_singlecolumn_with_steps.py data/10/linearroad-CCR/5/600/lr_rate.csv data/exp15/merged.csv data/exp15/policies_linear.pdf linearroad`
# - `python plotting/paper_plot_agent_policies_icpe_singlecolumn_with_steps.py data/10/synthetic-CCR/1/900/s_rate.csv data/exp15/merged.csv data/exp15/policies_synthetic.pdf synthetic`

# %% [markdown]
# I want to create another policies plot for synthetic but using for WEL-AW the runs from 150 to 300
#
# First, create a folder and get the data
# - `mkdir -p data/exp15/WEL-AW/15.2/synthetic`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15.1/synthetic data/exp15/WEL-AW/15.2/`
# - `./scripts/create_plots_for_exp.sh data/exp15/WEL-AW True 15.2/synthetic`
# - `python plotting/create_summary_data.py data/exp15/WEL-AW/15.2`
#
# Now I am modifying manually data/exp15/WEL-AW/15.2/baselines_data.csv to change synthetic into welaw_synthetic
#
# I am creating a copy of data/exp15/merged.csv for this plot
# - `cp data/exp15/merged.csv data/exp15/merged_weaaw_synthetic_runs_150_300.csv`
#
# Manually replacing data
#
# re-running script
# - `python plotting/paper_plot_agent_policies_icpe_singlecolumn_with_steps.py data/10/synthetic-CCR/1/900/s_rate.csv data/exp15/merged_weaaw_synthetic_runs_150_300.csv data/exp15/policies_synthetic_welaw_150_300.pdf synthetic`

# %% [markdown]
# Creating new plots for 150 fresh runs with the 4 policies.
#
# The idea is to check if the trends are similar to the previous four runs
#
# I will also try to use the same folder structure used by Jingyu, in case it speeds up things
# - `mkdir -p data/exp15.4`
# - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp15_4/. data/exp15.4`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 1_WEAOB/synthetic`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 1_WEAOB/linear/normal`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 2_EAOB/synthetic`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 2_EAOB/linear`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 3_AOB/synthetic`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 3_AOB/linear`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 4_WEAAW/synthetic`
# - `./scripts/create_plots_for_exp.sh data/exp15.4 False 4_WEAAW/linear`
#
#
# - `python plotting/create_summary_data.py data/exp15.4/1_WEAOB`
# - `python plotting/create_summary_data.py data/exp15.4/2_EAOB`
# - `python plotting/create_summary_data.py data/exp15.4/3_AOB`
# - `python plotting/create_summary_data.py data/exp15.4/4_WEAAW`
#
# Manually modifying labels insde the baselines_data files
#
# - `find data/exp15.4/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp15.4/merged.csv`
#
# Remving extra headers
#
# - `python plotting/paper_plot_agent_policies_icpe_singlecolumn_with_steps.py data/10/linearroad-CCR/5/600/lr_rate.csv data/exp15.4/merged.csv data/exp15.4/policies_linear.pdf linearroad`
# - `python plotting/paper_plot_agent_policies_icpe_singlecolumn_with_steps.py data/10/synthetic-CCR/1/900/s_rate.csv data/exp15.4/merged.csv data/exp15.4/policies_synthetic.pdf synthetic`

# %% [markdown]
# I want to inspect a bit the times in-between actions for the different policies
#
# Write a python script that, given a folder, search for all the files names episodes.csv recursively. Each file has the following columns ts,episode,event. The script should print the full path of each file and the average ts difference for consecutive events of type "action" for the same episode
#
# I am saving this in a script named actions_times.py
