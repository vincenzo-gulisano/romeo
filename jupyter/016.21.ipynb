# %% [markdown]
# # synthetic with entropy

# %% [markdown]
# ## What rewards do we get? Are these the expected ones?
#
# - `python plotting/actions_rewards.py data/exp16.21`

# %% [markdown]
# yes, various

# %% [markdown]
# ## Are the durations across actions the expected ones?
#
# - `python plotting/actions_times.py data/exp16.21`

# %% [markdown]
# yes

# %% [markdown]
# ## Termination
# - How many terminate because of CPU?
# - How many terminate because of latency?
# - How many terminate because of CPU & Latency?
#
# ```
# find $1 -type f -name "python_agent.log" -exec bash -c '
#   for file; do
#     echo "Processing $file"
#     cpu_count=$(grep -c "High cpu observed" "$file")
#     latency_count=$(grep -c "High latency observed" "$file")
#     echo "High CPU observed: $cpu_count"
#     echo "High Latency observed: $latency_count"
#   done
# ' bash {} +
# ```

# %% [markdown]
# Almost always CPU

# %% [markdown]
# ### Prepare data
#
# ```
# ./scripts/create_plots_for_exp.sh data/exp16.21 False WELOB/synthetic5s
# python plotting/create_summary_data.py data/exp16.21/WELOB
# ./scripts/create_plots_for_exp.sh data/exp16.21 False ELOB/synthetic5s
# python plotting/create_summary_data.py data/exp16.21/ELOB
# ./scripts/create_plots_for_exp.sh data/exp16.21 False LOB/synthetic5s
# python plotting/create_summary_data.py data/exp16.21/LOB
# ./scripts/create_plots_for_exp.sh data/exp16.21 False WELAW/synthetic5s
# python plotting/create_summary_data.py data/exp16.21/WELAW
# sed -i '' 's/synthetic/welob_synthetic/g' data/exp16.21/WELOB/baselines_data.csv
# sed -i '' 's/synthetic/elob_synthetic/g' data/exp16.21/ELOB/baselines_data.csv
# sed -i '' 's/synthetic/lob_synthetic/g' data/exp16.21/LOB/baselines_data.csv
# sed -i '' 's/synthetic/welaw_synthetic/g' data/exp16.21/WELAW/baselines_data.csv
# find data/exp16.21/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp16.21/merged.csv
# python plotting/plot_probs_evolution.py data/exp16.21
# python plotting/plot_cumulative_reward.py data/exp16.21/ 1001 3100
# ```

# %% [markdown]
# ## Steps and rewards

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.21/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic5s.steps.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic5s.steps.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
        <td><img src="{path_to_image}WELAW_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic5s.reward.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic5s.reward.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
        <td><img src="{path_to_image}WELAW_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.21/WELOB_synthetic5s.steps.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/ELOB_synthetic5s.steps.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.21/LOB_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
#         <td><img src="../data/exp16.21/WELAW_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.21/WELOB_synthetic5s.reward.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/ELOB_synthetic5s.reward.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.21/LOB_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
#         <td><img src="../data/exp16.21/WELAW_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Seems consistent with stuff seen before

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.21/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}ELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}LOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELAW/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.21/WELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/WELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/WELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.21/ELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/ELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/ELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.21/LOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/LOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/LOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.21/WELAW/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/WELAW/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.21/WELAW/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# ## final graph
#
# - modify manually the merged file
# - `python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.21/merged.csv data/exp16.21/s_baseline_vs_multiple_agents.pdf data/exp16.21/s_baseline_vs_multiple_agents.png synthetic welaw_synthetic5s welob_synthetic5s,elob_synthetic5s,lob_synthetic5s,welaw_synthetic5s WEL-OB,EL-OB,L-OB,WEL-AW`

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.18/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.18/s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Modify the script so that we mark the areas in which the moving average is below the threshold (will be relevant for linear I think)
