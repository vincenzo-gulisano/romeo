# %% [markdown]
# # Linear Road and Synthetic with entropy and compression rewards

# %% [markdown]
# ## What rewards do we get? Are these the expected ones?
#
# - `python plotting/actions_rewards.py data/exp16-5`

# %% [markdown]
# - Seems correct, yes

# %% [markdown]
# ## Are the durations across actions the expected ones?
#
# - `python plotting/actions_times.py data/exp16-5`

# %% [markdown]
# Usual ones, yes

# %% [markdown]
# ## Termination
# - How many terminate because of CPU?
# - How many terminate because of latency?
# - How many terminate because of CPU & Latency?
#
# ```
# find $1 -type f -name "python_agent.log" -exec bash -c '
#   for file; do
#     echo "Processing $file"
#     cpu_count=$(grep -c "High cpu observed" "$file")
#     latency_count=$(grep -c "High latency observed" "$file")
#     echo "High CPU observed: $cpu_count"
#     echo "High Latency observed: $latency_count"
#   done
# ' bash {} +
# ```

# %% [markdown]
# Always latency based, no CPU

# %% [markdown]
# ### Prepare data
#
# ```
# ./scripts/create_plots_for_exp.sh data/exp16-5 False WELOB/synthetic
# ./scripts/create_plots_for_exp.sh data/exp16-5 False WELOB/linear
# python plotting/create_summary_data.py data/exp16-5/WELOB
# ./scripts/create_plots_for_exp.sh data/exp16-5 False ELOB/linear
# ./scripts/create_plots_for_exp.sh data/exp16-5 False ELOB/synthetic
# python plotting/create_summary_data.py data/exp16-5/ELOB
# ./scripts/create_plots_for_exp.sh data/exp16-5 False LOB/linear
# ./scripts/create_plots_for_exp.sh data/exp16-5 False LOB/synthetic
# python plotting/create_summary_data.py data/exp16-5/LOB
# ./scripts/create_plots_for_exp.sh data/exp16-5 False WELAW/linear
# ./scripts/create_plots_for_exp.sh data/exp16-5 False WELAW/synthetic
# python plotting/create_summary_data.py data/exp16-5/WELAW
# sed -i '' 's/linear/welob_linear/g' data/exp16-5/WELOB/baselines_data.csv
# sed -i '' 's/linear/elob_linear/g' data/exp16-5/ELOB/baselines_data.csv
# sed -i '' 's/linear/lob_linear/g' data/exp16-5/LOB/baselines_data.csv
# sed -i '' 's/linear/welaw_linear/g' data/exp16-5/WELAW/baselines_data.csv
# sed -i '' 's/synthetic/welob_synthetic/g' data/exp16.19/WELOB/baselines_data.csv
# sed -i '' 's/synthetic/elob_synthetic/g' data/exp16.19/ELOB/baselines_data.csv
# sed -i '' 's/synthetic/lob_synthetic/g' data/exp16.19/LOB/baselines_data.csv
# sed -i '' 's/synthetic/welaw_synthetic/g' data/exp16.19/WELAW/baselines_data.csv
# find data/exp16-5/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp16-5/merged.csv
# python plotting/plot_probs_evolution.py data/exp16-5
# python plotting/plot_cumulative_reward.py data/exp16-5/ 1001 3100
# ```

# %% [markdown]
# ## Steps and rewards

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16-5/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB_linear.steps.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_linear.steps.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_linear.steps.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_linear.steps.png" alt="Image 3" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELOB_linear.reward.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_linear.reward.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_linear.reward.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_linear.reward.png" alt="Image 3" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16-5/WELOB_linear.steps.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB_linear.steps.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16-5/LOB_linear.steps.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16-5/WELAW_linear.steps.png" alt="Image 3" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16-5/WELOB_linear.reward.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB_linear.reward.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16-5/LOB_linear.reward.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16-5/WELAW_linear.reward.png" alt="Image 3" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Seems consistent with stuff seen before

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16-5/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}ELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}LOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELAW/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16-5/WELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/WELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/WELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16-5/ELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16-5/LOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/LOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
# ...

# %% [markdown]
# ## final graph
#
# - modify manually the merged file
# - `python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16-5/merged.csv data/exp16-5/lr_baseline_vs_multiple_agents.pdf data/exp16-5/lr_baseline_vs_multiple_agents.png linearroad welaw_linear welob_linear,elob_linear,lob_linear,welaw_linear WEL-OB,EL-OB,L-OB,WEL-AW`

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16-5/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}lr_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16-5/lr_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16-5/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic.steps.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic.steps.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic.steps.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_synthetic.steps.png" alt="Image 3" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic.reward.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic.reward.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic.reward.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_synthetic.reward.png" alt="Image 3" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16-5/WELOB_synthetic.steps.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB_synthetic.steps.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16-5/LOB_synthetic.steps.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16-5/WELAW_synthetic.steps.png" alt="Image 3" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16-5/WELOB_synthetic.reward.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB_synthetic.reward.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16-5/LOB_synthetic.reward.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16-5/WELAW_synthetic.reward.png" alt="Image 3" width="450"/></td>
#     </tr>
# </table>

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16-5/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}ELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}LOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELAW/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16-5/WELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/WELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/WELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16-5/ELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/ELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16-5/LOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16-5/LOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
# ...

# %% [markdown]
# ## final graph
#
# - modify manually the merged file
# - `python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16-5/merged.csv data/exp16-5/s_baseline_vs_multiple_agents.pdf data/exp16-5/s_baseline_vs_multiple_agents.png synthetic welaw_synthetic welob_synthetic,elob_synthetic,lob_synthetic,welaw_synthetic WEL-OB,EL-OB,L-OB,WEL-AW`

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16-5/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16-5/s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>
