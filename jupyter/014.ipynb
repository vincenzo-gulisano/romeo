# %% [markdown]
# - `mkdir data/exp14/WEAAW/synthetic/14.1`
# - `./scripts/create_plots_for_exp.sh`
# - `python plotting/create_summary_data.py data/exp14/WEAAW/synthetic`
# - `python plotting/paper_plot_baselines_vs_agent.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp14/WEAAW/synthetic/baselines_data.csv data/exp14/WEAAW/synthetic/s_baseline_vs_agent.pdf data/exp14/WEAAW/synthetic/14.1/actionsprobs.csv 181`
