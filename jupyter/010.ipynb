# %% [markdown]
# Creating plots from 200 episodes of Exp10 for LinearRoad
#
#
# Got the data from michelangelo
#
# I updated
#
# ```
# nano ./scripts/create_plots_for_exp.sh
# ```
#
# So that in the beginning it has
#
# ```
# #!/bin/bash
# base_exp_folder="./data/10"
# folders_to_explore=(linearroad-RL)
# ```
#
# Run it
#
# Now each folder contains a file named `compressionandepisodesstats.csv`
#
# `python plotting/create_summary_data.py data/10/`
#
# `python plotting/plot_summary_data.py data/10/`

# %% [markdown]
# Now preparing baseline graphs for synthetic
#
# - copied the data
# - updated `create_plots_for_exp.sh`
# - running it
# - committing everything and synchronizing on michelangelo to create the input rate data for the plot
# - Added `create_input_rate_data_synthetic.py` on michelangelo, created the data file and committed
# - Run `python plotting/create_summary_data.py data/synthetic-CCR/900/`
