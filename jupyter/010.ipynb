# %% [markdown]
# Creating plots from 200 episodes of Exp10 for LinearRoad
#
#
# Got the data from michelangelo
#
# I updated
#
# ```
# nano ./scripts/create_plots_for_exp.sh
# ```
#
# So that in the beginning it has
#
# ```
# #!/bin/bash
# base_exp_folder="./data/10"
# folders_to_explore=(linearroad-RL)
# ```
#
# Run it
#
# Now each folder contains a file named `compressionandepisodesstats.csv`
#
# `python plotting/create_summary_data.py data/10/`
#
# `python plotting/plot_summary_data.py data/10/`

# %% [markdown]
# recreating the baseline plots for linear road on this mac
#
# Updating ./scripts/create_plots_for_exp.sh
#
# Made a bit of a mess with folders, but eventually it looks like this
#
# `python plotting/plot_baselines_scatterplots.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/10/linearroad-RL/5/600/baselines_data.csv`

# %% [markdown]
# - Copying data for experiments 10.1 and 10.2 from Michelangelo
# - The idea is to plot the result and confirm that in this case too the agent is too conservative
# - Copy things
#   - /Users/vinmas/repositories/romeo/data/10/linearroad-RL/5/600/exp10.2
#   - /Users/vinmas/repositories/romeo/data/10/synthetic-RL/1/900/exp10.1
#   - /Users/vinmas/repositories/romeo/data/10/synthetic-RL/1/900/exp10.2
# - create_plots_for_exp for each one of them
# - Create the baseline data (this will contain all the RL agents)
#   - python plotting/create_summary_data.py data/10/synthetic-RL/1/900/
#   - python plotting/create_summary_data.py data/10/linearroad-RL/5/600/
# - Create the graph
#   - python plotting/plot_baselines_scatterplots.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/10/linearroad-RL/5/600/baselines_data.csv
#     - Notice I modified manually the id for the RL baseline between exp10 and exp10.2
