# %% [markdown]
# # synthetic with entropy

# %% [markdown]
# ## What rewards do we get? Are these the expected ones?
#
# - `python plotting/actions_rewards.py data/exp16.16`

# %% [markdown]
# ```
# data/exp16.16/ELOB/synthetic/probs.csv: reward
# 0     6311
# 30     649
#
# data/exp16.16/LOB/synthetic/probs.csv: reward
# 0     7975
# 30     823
#
# data/exp16.16/WELOB/synthetic/probs.csv: reward
# 0     15425
# 30     1653
#
# data/exp16.16/WELAW/synthetic/probs.csv: reward
# 0     6155
# 30     627
#
# and all rewards from the SPE are 0, so yes
# ```

# %% [markdown]
# ## Are the durations across actions the expected ones?
#
# - `python plotting/actions_times.py data/exp16.16`

# %% [markdown]
# ```
# File: data/exp16.16/WELOB/synthetic/episodes.csv - Average ts difference: 0.11
# File: data/exp16.16/ELOB/synthetic/episodes.csv - Average ts difference: 1.00
# File: data/exp16.16/LOB/synthetic/episodes.csv - Average ts difference: 1.75
# File: data/exp16.16/WELAW/synthetic/episodes.csv - Average ts difference: 1.69
# so yes...
# ```

# %% [markdown]
# ## Termination
# - How many terminate because of CPU?
# - How many terminate because of latency?
# - How many terminate because of CPU & Latency?
#
# ```
# find $1 -type f -name "python_agent.log" -exec bash -c '
#   for file; do
#     echo "Processing $file"
#     cpu_count=$(grep -c "High cpu observed" "$file")
#     latency_count=$(grep -c "High latency observed" "$file")
#     echo "High CPU observed: $cpu_count"
#     echo "High Latency observed: $latency_count"
#   done
# ' bash {} +
# ```

# %% [markdown]
# ```
# Processing data/exp16.16/WELOB/synthetic/python_agent.log
# High CPU observed: 0
# High Latency observed: 120
# Processing data/exp16.16/ELOB/synthetic/python_agent.log
# High CPU observed: 0
# High Latency observed: 120
# Processing data/exp16.16/LOB/synthetic/python_agent.log
# High CPU observed: 0
# High Latency observed: 120
# Processing data/exp16.16/WELAW/synthetic/python_agent.log
# High CPU observed: 0
# High Latency observed: 120
# Consistent with the previous one
# ```

# %% [markdown]
# ### Prepare data
#
# ```
# ./scripts/create_plots_for_exp.sh data/exp16.16 False WELOB/synthetic
# python plotting/create_summary_data.py data/exp16.16/WELOB
# ./scripts/create_plots_for_exp.sh data/exp16.16 False ELOB/synthetic
# python plotting/create_summary_data.py data/exp16.16/ELOB
# ./scripts/create_plots_for_exp.sh data/exp16.16 False LOB/synthetic
# python plotting/create_summary_data.py data/exp16.16/LOB
# ./scripts/create_plots_for_exp.sh data/exp16.16 False WELAW/synthetic
# python plotting/create_summary_data.py data/exp16.16/WELAW
# sed -i '' 's/synthetic/welob_synthetic/g' data/exp16.16/WELOB/baselines_data.csv
# sed -i '' 's/synthetic/elob_synthetic/g' data/exp16.16/ELOB/baselines_data.csv
# sed -i '' 's/synthetic/lob_synthetic/g' data/exp16.16/LOB/baselines_data.csv
# sed -i '' 's/synthetic/welaw_synthetic/g' data/exp16.16/WELAW/baselines_data.csv
# find data/exp16.16/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp16.16/merged.csv
# python plotting/plot_probs_evolution.py data/exp16.16
# python plotting/plot_probs_evolution.py data/exp16.16
# python plotting/plot_cumulative_reward.py data/exp16.16/ 1001 3100
# ```

# %% [markdown]
# ## Steps and rewards

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.16/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic.steps.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic.steps.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic.steps.png" alt="Image 3" width="450"/></td>
        <td><img src="{path_to_image}WELAW_synthetic.steps.png" alt="Image 3" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic.reward.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic.reward.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic.reward.png" alt="Image 3" width="450"/></td>
        <td><img src="{path_to_image}WELAW_synthetic.reward.png" alt="Image 3" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.16/WELOB_synthetic.steps.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/ELOB_synthetic.steps.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.16/LOB_synthetic.steps.png" alt="Image 3" width="450"/></td>
#         <td><img src="../data/exp16.16/WELAW_synthetic.steps.png" alt="Image 3" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.16/WELOB_synthetic.reward.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/ELOB_synthetic.reward.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.16/LOB_synthetic.reward.png" alt="Image 3" width="450"/></td>
#         <td><img src="../data/exp16.16/WELAW_synthetic.reward.png" alt="Image 3" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Seems consistent with stuff seen before

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.16/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}ELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}LOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELAW/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.16/WELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/WELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/WELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.16/ELOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/ELOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/ELOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.16/LOB/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/LOB/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/LOB/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.16/WELAW/synthetic/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/WELAW/synthetic/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.16/WELAW/synthetic/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# ## final graph
#
# - modify manually the merged file
# - `python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.16/merged.csv data/exp16.16/s_baseline_vs_multiple_agents.pdf data/exp16.16/s_baseline_vs_multiple_agents.png synthetic welaw_synthetic welob_synthetic,elob_synthetic,lob_synthetic,welaw_synthetic WEL-OB,EL-OB,L-OB,WEL-AW`

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.16/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.16/s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Modify the script so that we mark the areas in which the moving average is below the threshold (will be relevant for linear I think)
