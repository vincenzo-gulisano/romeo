# %% [markdown]
# - checking results of new experiments with always 80 steps and +10 points if latency at the end is good and 0.999 gamma
# - synthetic first
# - get the data
#   - `mkdir data/exp13/4.1_WEAAW/weaaw_synthetic/`
#   - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/WEAAW/synthetic/1/900/5000000000/10/. data/exp13/4.1_WEAAW/weaaw_synthetic/`
#   - `./scripts/create_plots_for_exp.sh` (modified as needed)
#   - `python plotting/create_summary_data.py data/exp13/4.1_WEAAW` (there was a missing return in python.log 1Episode, had to modify manually...)
#   - `python plotting/paper_plot_baselines_vs_agent.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp13/4.1_WEAAW/baselines_data.csv data/exp13/s_baseline_vs_agent_80stes.pdf data/exp13/4.1_WEAAW/weaaw_synthetic/actionsprobs.csv 81`

# %% [markdown]
# - now checking 20 more runs with tau fixed at 1
# - the idea is that probabilities become more accentuated, and if the learning is there, actions are also clearer
# - I'm going to have a look at the python log first
#   - `mkdir data/exp13/4.2_WEAAW/weaaw_synthetic`
