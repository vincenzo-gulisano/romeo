# %% [markdown]
# # Linear Road with entropy

# %% [markdown]
# ## What rewards do we get? Are these the expected ones?
#
# - `python plotting/actions_rewards.py data/exp16.17`

# %% [markdown]
# ```
#
#
# data/exp16.17/WELOB/linear/probs.csv: reward
#  0     36353
# -1     25393
#  30     4013
#  25     2817
#
# data/exp16.17/ELOB/linear/probs.csv: reward
# 0     30866
# 30     3382
#
# data/exp16.17/LOB/linear/probs.csv: reward
#  0     20738
#  30     2247
# -1       568
#  25       62
#
# data/exp16.17/WELAW/linear/probs.csv: reward
# 0     23280
# 30     2543
# ```
#
# All rewards from the SPE are 0, so that is as expected. Interesting ELOB did not result in entropy-based corrections, but LOB did. Notice WELAW was not completed yet, so results might differ

# %% [markdown]
# ## Are the durations across actions the expected ones?
#
# - `python plotting/actions_times.py data/exp16.17`

# %% [markdown]
# ```
# File: data/exp16.17/WELOB/linear/episodes.csv - Average ts difference: 0.11
# File: data/exp16.17/ELOB/linear/episodes.csv - Average ts difference: 1.00
# File: data/exp16.17/LOB/linear/episodes.csv - Average ts difference: 1.89
# File: data/exp16.17/WELAW/linear/episodes.csv - Average ts difference: 4.99
# ```
#
# so yes...

# %% [markdown]
# ## Termination
# - How many terminate because of CPU?
# - How many terminate because of latency?
# - How many terminate because of CPU & Latency?
#
# ```
# find $1 -type f -name "python_agent.log" -exec bash -c '
#   for file; do
#     echo "Processing $file"
#     cpu_count=$(grep -c "High cpu observed" "$file")
#     latency_count=$(grep -c "High latency observed" "$file")
#     echo "High CPU observed: $cpu_count"
#     echo "High Latency observed: $latency_count"
#   done
# ' bash {} +
# ```

# %% [markdown]
# ```
# Processing data/exp16.17/WELOB/linear/python_agent.log
# High CPU observed: 60
# High Latency observed: 2
# Processing data/exp16.17/ELOB/linear/python_agent.log
# High CPU observed: 110
# High Latency observed: 20
# Processing data/exp16.17/LOB/linear/python_agent.log
# High CPU observed: 115
# High Latency observed: 27
# Processing data/exp16.17/WELAW/linear/python_agent.log
# High CPU observed: 89
# High Latency observed: 5
# ```
# While most of the experiment should terminate earlier for ELOB and LOB, it seems many completed for WELOB. Since WELOB required entropy corrections, I guess the dominat action was 1 or 2 then?
#
# Notice WELAW was not completed yet, so results might differ. The sub for WELAW is less than 100 (the number of episodes run so far) but is OK, we know several episodes reach 1000

# %% [markdown]
# ### Prepare data
#
# ```
# ./scripts/create_plots_for_exp.sh data/exp16.17 False WELOB/linear
# python plotting/create_summary_data.py data/exp16.17/WELOB
# ./scripts/create_plots_for_exp.sh data/exp16.17 False ELOB/linear
# python plotting/create_summary_data.py data/exp16.17/ELOB
# ./scripts/create_plots_for_exp.sh data/exp16.17 False LOB/linear
# python plotting/create_summary_data.py data/exp16.17/LOB
# ./scripts/create_plots_for_exp.sh data/exp16.17 False WELAW/linear
# python plotting/create_summary_data.py data/exp16.17/WELAW
# sed -i '' 's/linear/welob_linear/g' data/exp16.17/WELOB/baselines_data.csv
# sed -i '' 's/linear/elob_linear/g' data/exp16.17/ELOB/baselines_data.csv
# sed -i '' 's/linear/lob_linear/g' data/exp16.17/LOB/baselines_data.csv
# sed -i '' 's/linear/welaw_linear/g' data/exp16.17/WELAW/baselines_data.csv
# find data/exp16.17/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp16.17/merged.csv
# python plotting/plot_probs_evolution.py data/exp16.17
# python plotting/plot_cumulative_reward.py data/exp16.17/ 1001 3100
# ```

# %% [markdown]
# ## Steps and rewards

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.17/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB_linear.steps.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_linear.steps.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_linear.steps.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_linear.steps.png" alt="Image 3" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELOB_linear.reward.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_linear.reward.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_linear.reward.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_linear.reward.png" alt="Image 3" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.17/WELOB_linear.steps.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.17/ELOB_linear.steps.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.17/LOB_linear.steps.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16.17/WELAW_linear.steps.png" alt="Image 3" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.17/WELOB_linear.reward.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.17/ELOB_linear.reward.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.17/LOB_linear.reward.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16.17/WELAW_linear.reward.png" alt="Image 3" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Seems consistent with stuff seen before

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.17/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}ELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}LOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELAW/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.17/WELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.17/WELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.17/WELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.17/ELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.17/ELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.17/ELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.17/LOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.17/LOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
# ...

# %% [markdown]
# ## final graph
#
# - modify manually the merged file
# - `python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16.17/merged.csv data/exp16.17/lr_baseline_vs_multiple_agents.pdf data/exp16.17/lr_baseline_vs_multiple_agents.png linearroad welaw_linear welob_linear,elob_linear,lob_linear,welaw_linear WEL-OB,EL-OB,L-OB,WEL-AW`

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.17/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))

# %% [markdown]
# Modify the script so that we mark the areas in which the moving average is below the threshold (will be relevant for linear I think)
