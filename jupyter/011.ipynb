# %% [markdown]
# - This is experiment 11
# - It's the synthetic usecase, the reward function is on delta (but only negative rewards when the latency exceeds the treshold)
# - but using softmax
# - `python plotting/create_summary_data.py data/11/synthetic-RL/1/900/`
# - `python plotting/plot_baselines_scatterplots.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/11/synthetic-RL/1/900/baselines_data.csv `
# - commit a05adf1f243e85f9817b2cd12636e6a49f3ba189

# %% [markdown]
# - checking exp11.1
