# %% [markdown]
# # synthetic with entropy

# %% [markdown]
# ## What rewards do we get? Are these the expected ones?
#
# - `python plotting/actions_rewards.py data/exp16.18`

# %% [markdown]
# ```
# data/exp16.18/WELOB/synthetic5s/probs.csv: reward
# 0     61417
# 30     6786
#
# data/exp16.18/ELOB/synthetic5s/probs.csv: reward
# 0     10387
# 30     1096
#
# data/exp16.18/LOB/synthetic5s/probs.csv: reward
# 0     21054
# 30     2286
#
# data/exp16.18/WELAW/synthetic5s/probs.csv: reward
# 0     16356
# 30     1759
#
# and all rewards from the SPE are 0, so yes
# ```

# %% [markdown]
# ## Are the durations across actions the expected ones?
#
# - `python plotting/actions_times.py data/exp16.18`

# %% [markdown]
# ```
# File: data/exp16.18/WELOB/synthetic5s/episodes.csv - Average ts difference: 0.11
# File: data/exp16.18/ELOB/synthetic5s/episodes.csv - Average ts difference: 1.00
# File: data/exp16.18/LOB/synthetic5s/episodes.csv - Average ts difference: 1.89
# File: data/exp16.18/WELAW/synthetic5s/episodes.csv - Average ts difference: 4.99
# so yes...
# ```

# %% [markdown]
# ## Termination
# - How many terminate because of CPU?
# - How many terminate because of latency?
# - How many terminate because of CPU & Latency?
#
# ```
# find $1 -type f -name "python_agent.log" -exec bash -c '
#   for file; do
#     echo "Processing $file"
#     cpu_count=$(grep -c "High cpu observed" "$file")
#     latency_count=$(grep -c "High latency observed" "$file")
#     echo "High CPU observed: $cpu_count"
#     echo "High Latency observed: $latency_count"
#   done
# ' bash {} +
# ```

# %% [markdown]
# ```
# Processing data/exp16.18/WELOB/synthetic5s/python_agent.log
# High CPU observed: 0
# High Latency observed: 76
# Processing data/exp16.18/ELOB/synthetic5s/python_agent.log
# High CPU observed: 0
# High Latency observed: 120
# Processing data/exp16.18/LOB/synthetic5s/python_agent.log
# High CPU observed: 115
# High Latency observed: 8
# Processing data/exp16.18/WELAW/synthetic5s/python_agent.log
# High CPU observed: 118
# High Latency observed: 4
# ```
#
# - WELOB CPU was 100
# - ELOB CPU was 100
# - LOB CPU was 98.9
# - WELAW CPU was 98.9
# So the lack of high CPU terminations for the first two is not to be trusted

# %% [markdown]
# ### Prepare data
#
# ```
# ./scripts/create_plots_for_exp.sh data/exp16.18 False WELOB/synthetic5s
# python plotting/create_summary_data.py data/exp16.18/WELOB
# ./scripts/create_plots_for_exp.sh data/exp16.18 False ELOB/synthetic5s
# python plotting/create_summary_data.py data/exp16.18/ELOB
# ./scripts/create_plots_for_exp.sh data/exp16.18 False LOB/synthetic5s
# python plotting/create_summary_data.py data/exp16.18/LOB
# ./scripts/create_plots_for_exp.sh data/exp16.18 False WELAW/synthetic5s
# python plotting/create_summary_data.py data/exp16.18/WELAW
# sed -i '' 's/synthetic/welob_synthetic/g' data/exp16.18/WELOB/baselines_data.csv
# sed -i '' 's/synthetic/elob_synthetic/g' data/exp16.18/ELOB/baselines_data.csv
# sed -i '' 's/synthetic/lob_synthetic/g' data/exp16.18/LOB/baselines_data.csv
# sed -i '' 's/synthetic/welaw_synthetic/g' data/exp16.18/WELAW/baselines_data.csv
# find data/exp16.18/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp16.18/merged.csv
# python plotting/plot_probs_evolution.py data/exp16.18
# python plotting/plot_cumulative_reward.py data/exp16.18/ 1001 3100
# ```

# %% [markdown]
# ## Steps and rewards

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.18/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic5s.steps.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic5s.steps.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
        <td><img src="{path_to_image}WELAW_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELOB_synthetic5s.reward.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_synthetic5s.reward.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
        <td><img src="{path_to_image}WELAW_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.18/WELOB_synthetic5s.steps.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.18/ELOB_synthetic5s.steps.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.18/LOB_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
#         <td><img src="../data/exp16.18/WELAW_synthetic5s.steps.png" alt="Image 3" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.18/WELOB_synthetic5s.reward.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.18/ELOB_synthetic5s.reward.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.18/LOB_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
#         <td><img src="../data/exp16.18/WELAW_synthetic5s.reward.png" alt="Image 3" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Seems consistent with stuff seen before

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.18/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}ELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}LOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELAW/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.18/WELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.18/WELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.18/WELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.18/ELOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.18/ELOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.18/ELOB/synthetic5s/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.18/LOB/synthetic5s/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.18/LOB/synthetic5s/probs_sum_probs.png" alt="Image 1" width="450"/></td>
# ...

# %% [markdown]
# ## final graph
#
# - modify manually the merged file
# - `python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.18/merged.csv data/exp16.18/s_baseline_vs_multiple_agents.pdf data/exp16.18/s_baseline_vs_multiple_agents.png synthetic welaw_synthetic5s welob_synthetic5s,elob_synthetic5s,lob_synthetic5s,welaw_synthetic5s WEL-OB,EL-OB,L-OB,WEL-AW`

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.18/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.18/s_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Modify the script so that we mark the areas in which the moving average is below the threshold (will be relevant for linear I think)
