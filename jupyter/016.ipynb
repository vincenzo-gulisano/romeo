# %% [markdown]
# 2024/10/03 - changed termination, state, reward

# %% [markdown]
# mkdir -p data/exp16.1/WELAW/synthetic
# mkdir -p data/exp16.1/LOB/synthetic
# mkdir -p data/exp16.1/ELOB/synthetic
# mkdir -p data/exp16.1/WELOB/synthetic
#
# mkdir -p data/exp16.1/WELAW/linear
# mkdir -p data/exp16.1/LOB/linear
# mkdir -p data/exp16.1/ELOB/linear
# mkdir -p data/exp16.1/WELOB/linear
#
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/WELAW/synthetic/1/900/5000000000/10/. data/exp16.1/WELAW/synthetic
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/LOB/synthetic/1/900/5000000000/10/. data/exp16.1/LOB/synthetic
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/ELOB/synthetic/1/900/5000000000/10/. data/exp16.1/ELOB/synthetic
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/WELOB/synthetic/1/900/5000000000/10/. data/exp16.1/WELOB/synthetic
#
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/WELAW/linear/5/600/5000000000/10/. data/exp16.1/WELAW/linear
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/LOB/linear/5/600/5000000000/10/. data/exp16.1/LOB/linear
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/ELOB/linear/5/600/5000000000/10/. data/exp16.1/ELOB/linear
# scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/data/output/WELOB/linear/5/600/5000000000/10/. data/exp16.1/WELOB/linear
#
# python plotting/actions_times.py data/exp16.1
#
# sleep 10
#
# ./scripts/create_plots_for_exp.sh data/exp16.1 False WELAW/synthetic
# ./scripts/create_plots_for_exp.sh data/exp16.1 False WELAW/linear
# python plotting/create_summary_data.py data/exp16.1/WELAW
#
# ./scripts/create_plots_for_exp.sh data/exp16.1 False LOB/synthetic
# ./scripts/create_plots_for_exp.sh data/exp16.1 False LOB/linear
# python plotting/create_summary_data.py data/exp16.1/LOB
#
# ./scripts/create_plots_for_exp.sh data/exp16.1 False ELOB/synthetic
# ./scripts/create_plots_for_exp.sh data/exp16.1 False ELOB/linear
# python plotting/create_summary_data.py data/exp16.1/ELOB
#
# ./scripts/create_plots_for_exp.sh data/exp16.1 False WELOB/synthetic
# ./scripts/create_plots_for_exp.sh data/exp16.1 False WELOB/linear
# python plotting/create_summary_data.py data/exp16.1/WELOB
#
# python plotting/actions_rewards.py data/exp16.1
#
# sed -i '' 's/linear/welob_linear/g' data/exp16.1/WELOB/baselines_data.csv
# sed -i '' 's/synthetic/welob_synthetic/g' data/exp16.1/WELOB/baselines_data.csv
# sed -i '' 's/linear/elob_linear/g' data/exp16.1/ELOB/baselines_data.csv
# sed -i '' 's/synthetic/elob_synthetic/g' data/exp16.1/ELOB/baselines_data.csv
# sed -i '' 's/linear/lob_linear/g' data/exp16.1/LOB/baselines_data.csv
# sed -i '' 's/synthetic/lob_synthetic/g' data/exp16.1/LOB/baselines_data.csv
# sed -i '' 's/linear/welaw_linear/g' data/exp16.1/WELAW/baselines_data.csv
# sed -i '' 's/synthetic/welaw_synthetic/g' data/exp16.1/WELAW/baselines_data.csv
#
# find data/exp16.1/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp16.1/merged.csv
# # Manually removing extra headers
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.1/WELAW/baselines_data.csv data/exp16.1/WELAW/synthetic/s_baseline_vs_agent.pdf synthetic welaw_synthetic
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16.1/WELAW/baselines_data.csv data/exp16.1/WELAW/linear/lr_baseline_vs_agent.pdf linearroad welaw_linear
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.1/LOB/baselines_data.csv data/exp16.1/LOB/synthetic/s_baseline_vs_agent.pdf synthetic lob_synthetic
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16.1/LOB/baselines_data.csv data/exp16.1/LOB/linear/lr_baseline_vs_agent.pdf linearroad lob_linear
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.1/ELOB/baselines_data.csv data/exp16.1/ELOB/synthetic/s_baseline_vs_agent.pdf synthetic elob_synthetic
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16.1/ELOB/baselines_data.csv data/exp16.1/ELOB/linear/lr_baseline_vs_agent.pdf linearroad elob_linear
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.1/WELOB/baselines_data.csv data/exp16.1/WELOB/synthetic/s_baseline_vs_agent.pdf synthetic welob_synthetic
#
# python plotting/paper_plot_baselines_vs_agent_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16.1/WELOB/baselines_data.csv data/exp16.1/WELOB/linear/lr_baseline_vs_agent.pdf linearroad welob_linear

# %% [markdown]
# created new script for new single column plot
#
#
# python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/synthetic-CCR/1/900 data/10/synthetic-CCR/1/900/s_rate.csv data/exp16.1/merged.csv data/exp16.1/s_baseline_vs_multiple_agents.pdf synthetic welaw_synthetic welob_synthetic,elob_synthetic,lob_synthetic,welaw_synthetic WEL-OB,EL-OB,L-OB,WEL-AW
#
# python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16.1/merged.csv data/exp16.1/lr_baseline_vs_multiple_agents.pdf linearroad welaw_linear welob_linear,elob_linear,lob_linear,welaw_linear WEL-OB,EL-OB,L-OB,WEL-AW
