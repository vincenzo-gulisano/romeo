# %% [markdown]
#
# - now checking what happens for 500 rounds of training and WEAOB policy for linear road and sysnthetic
# - Get the data
#   - `mkdir data/exp13/1.1_WEAOB`
#   - `mkdir data/exp13/1.1_WEAOB/weaob_linear/`
#   - `mkdir data/exp13/1.1_WEAOB/weaob_synthetic/`
#   - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp13.1/1_WEAOB/weaob_linear/. data/exp13/1.1_WEAOB/weaob_linear`
#   - `scp -r vincenzo@michelangelo.cse.chalmers.se:/home/jingyu/romeo/image/Exp13.1/1_WEAOB/weaob_synthetic/. data/exp13/1.1_WEAOB/weaob_synthetic`
