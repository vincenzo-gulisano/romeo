# %% [markdown]
# # Linear Road with entropy and compression rewards

# %% [markdown]
# ## What rewards do we get? Are these the expected ones?
#
# - `python plotting/actions_rewards.py data/exp16.20`

# %% [markdown]
# - From SPE always 0
# - From Agent high variability, as expeted. Cannot say if negative but that can be checked later on with the following graphs

# %% [markdown]
# ## Are the durations across actions the expected ones?
#
# - `python plotting/actions_times.py data/exp16.17`

# %% [markdown]
# Usual ones, yes

# %% [markdown]
# ## Termination
# - How many terminate because of CPU?
# - How many terminate because of latency?
# - How many terminate because of CPU & Latency?
#
# ```
# find $1 -type f -name "python_agent.log" -exec bash -c '
#   for file; do
#     echo "Processing $file"
#     cpu_count=$(grep -c "High cpu observed" "$file")
#     latency_count=$(grep -c "High latency observed" "$file")
#     echo "High CPU observed: $cpu_count"
#     echo "High Latency observed: $latency_count"
#   done
# ' bash {} +
# ```

# %% [markdown]
# ```
# Processing data/exp16.20//WELOB/linear/python_agent.log
# High CPU observed: 73
# High Latency observed: 1
# Processing data/exp16.20//ELOB/linear/python_agent.log
# High CPU observed: 108
# High Latency observed: 21
# Processing data/exp16.20//LOB/linear/python_agent.log
# High CPU observed: 115
# High Latency observed: 29
# Processing data/exp16.20//WELAW/linear/python_agent.log
# High CPU observed: 120
# High Latency observed: 4
# ```
# It's mostly CPU, and the longer the inter-action time, the higher the number of early termination because of CPU. The threshold is 90.0

# %% [markdown]
# ### Prepare data
#
# ```
# ./scripts/create_plots_for_exp.sh data/exp16.20 False WELOB/linear
# python plotting/create_summary_data.py data/exp16.20/WELOB
# ./scripts/create_plots_for_exp.sh data/exp16.20 False ELOB/linear
# python plotting/create_summary_data.py data/exp16.20/ELOB
# ./scripts/create_plots_for_exp.sh data/exp16.20 False LOB/linear
# python plotting/create_summary_data.py data/exp16.20/LOB
# ./scripts/create_plots_for_exp.sh data/exp16.20 False WELAW/linear
# python plotting/create_summary_data.py data/exp16.20/WELAW
# sed -i '' 's/linear/welob_linear/g' data/exp16.20/WELOB/baselines_data.csv
# sed -i '' 's/linear/elob_linear/g' data/exp16.20/ELOB/baselines_data.csv
# sed -i '' 's/linear/lob_linear/g' data/exp16.20/LOB/baselines_data.csv
# sed -i '' 's/linear/welaw_linear/g' data/exp16.20/WELAW/baselines_data.csv
# find data/exp16.20/ -type f -name "baselines_data.csv" -exec cat {} + > data/exp16.20/merged.csv
# python plotting/plot_probs_evolution.py data/exp16.20
# python plotting/plot_cumulative_reward.py data/exp16.20/ 1001 3100
# ```

# %% [markdown]
# ## Steps and rewards

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.20/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB_linear.steps.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_linear.steps.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_linear.steps.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_linear.steps.png" alt="Image 3" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELOB_linear.reward.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB_linear.reward.png" alt="Image 2" width="450"/></td>
        <td><img src="{path_to_image}LOB_linear.reward.png" alt="Image 3" width="450"/></td>
        # <td><img src="{path_to_image}WELAW_linear.reward.png" alt="Image 3" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.20/WELOB_linear.steps.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/ELOB_linear.steps.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.20/LOB_linear.steps.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16.20/WELAW_linear.steps.png" alt="Image 3" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.20/WELOB_linear.reward.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/ELOB_linear.reward.png" alt="Image 2" width="450"/></td>
#         <td><img src="../data/exp16.20/LOB_linear.reward.png" alt="Image 3" width="450"/></td>
#         # <td><img src="../data/exp16.20/WELAW_linear.reward.png" alt="Image 3" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Seems consistent with stuff seen before

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.20/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}WELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}ELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}ELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}LOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}LOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
    <tr>
        <td><img src="{path_to_image}WELAW/linear/probs_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
        <td><img src="{path_to_image}WELAW/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.20/WELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/WELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/WELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.20/ELOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/ELOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/ELOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.20/LOB/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/LOB/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/LOB/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
#     <tr>
#         <td><img src="../data/exp16.20/WELAW/linear/probs_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/WELAW/linear/probs_sum_probs.png" alt="Image 1" width="450"/></td>
#         <td><img src="../data/exp16.20/WELAW/linear/probs_entropy.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# ## final graph
#
# - modify manually the merged file
# - `python plotting/paper_plot_baselines_vs_multiple_agents_icpe_single_column.py data/10/linearroad-CCR/5/600 data/10/linearroad-CCR/5/600/lr_rate.csv data/exp16.20/merged.csv data/exp16.20/lr_baseline_vs_multiple_agents.pdf data/exp16.20/lr_baseline_vs_multiple_agents.png linearroad welaw_linear welob_linear,elob_linear,lob_linear,welaw_linear WEL-OB,EL-OB,L-OB,WEL-AW`

# %%
from IPython.display import display, Markdown

# Define your image folder path
path_to_image = "../data/exp16.20/"

# Create a Markdown string with the table and images
markdown_table = f"""
<table>
    <tr>
        <td><img src="{path_to_image}lr_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
    </tr>
</table>
"""

# Render the Markdown
display(Markdown(markdown_table))
# Out:
# <table>
#     <tr>
#         <td><img src="../data/exp16.20/lr_baseline_vs_multiple_agents.png" alt="Image 1" width="450"/></td>
#     </tr>
# </table>

# %% [markdown]
# Modify the script so that we mark the areas in which the moving average is below the threshold (will be relevant for linear I think)
